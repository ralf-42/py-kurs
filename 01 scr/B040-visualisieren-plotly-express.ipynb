# %% [markdown]
# <p><font size="6" color='grey'> <b>
# Visualisieren mit Plotly Express
# </b></font> </br></p>
# <p><font size="5" color='grey'> <b>
# Grundlagen
# </b></font> </br></p>
#
#
#
# ---

# %% [markdown]
# ![analytics-g8251ff258_1920 (Klein).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Bild von <a href="https://pixabay.com/de/users/tumisu-148124/?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=3265840">Tumisu</a> auf <a href="https://pixabay.com/de//?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=3265840">Pixabay</a>

# %% [markdown]
# # **0 <font color='orange'>|</font> Prolog**
# ---

# %% [markdown]
# Visualisierung ist ein leistungsstarkes Werkzeug, um eine Geschichte über Datensätze oder Analysen zu erzählen. Bei richtiger Ausführung zeigt die Visualisierung nicht nur Daten an, sondern hilft dem Publikum auch, wichtige Informationen zu verdauen. In der Welt, in der wir leben, gibt es jedoch überall schlechte Kommunikation. Ein Grund dafür ist, dass die Menschen die Daten hinter dem von ihnen erstellten Diagramm nicht verstehen. Manchmal soll es irreführen oder schockieren. Manchmal ist es gut gemeint, aber das Publikum interpretiert es einfach falsch. Um die oben genannten Umstände zu vermeiden, ist es unabhängig davon, in welchem ​​​​Bereich Sie tätig sind, besser, mehr über Visualisierung zu wissen.

# %% [markdown]
# [Crash Vizualization](https://vecco-insight.gitbook.io/crash-visualization/)

# %% [markdown]
# # **1 <font color='orange'>|</font> Plotly-Express**
# ---

# %% [markdown]
# Die Python-Grafikbibliothek von Plotly erstellt interaktive Grafiken in Veröffentlichungsqualität. Beispiele für die Erstellung von Liniendiagrammen, Streudiagrammen, Flächendiagrammen, Balkendiagrammen, Fehlerbalken, Boxplots, Histogrammen, Heatmaps, Subplots, mehreren Achsen, Polardiagrammen und Blasendiagrammen. Plotly.py ist kostenlos und Open Source und Sie können die Quelle anzeigen, Probleme melden oder auf GitHub beitragen.
#
#
# [Home](https://plotly.com/python/)
# [Github](https://github.com/plotly/plotly.py)
# [Data Packages](https://plotly.github.io/plotly.py-docs/generated/plotly.data.html#)

# %% [markdown]
# # **2 <font color='orange'>|</font> Überblick Visuals**
# ---

# %% [markdown]
# Plotly Express (px) ist ein integrierter Teil der Plotlylibrary und der empfohlene Ausgangspunkt für die Erstellung der gängigsten Figuren. Jede Funktion von Plotly Express verwendet intern Diagrammobjekte und gibt eine Abbildungsinstanz zurück. Plotly Express bietet mehr als 30 Funktionen zum Erstellen verschiedener Arten von Zahlen, von einem Streudiagramm über ein Balkendiagramm bis hin zu einem Histogramm und einem Sunburst-Diagramm während einer Datenexplorationssitzung.

# %% [markdown]
# | Type             |  Visual                                                         |
# |------------------|-----------------------------------------------------------------|
# | Basics           |  scatter, line, area, bar, funnel, timeline                     |
# | Part-of-Whole    |  pie, sunburst, treemap, funnel_area                            |
# | 1D Distributions |  histogram, box, violin, strip                                  |
# | 2D Distributions |  density_heatmap, density_contour                               |
# | Matrix Input     |  imshow                                                         |
# | 3-Dimensional    |  scatter_3d, line_3d                                            |
# | Multidimensional |  scatter_matrix, parallel_coordinates, parallel_categories      |
# | Tile Maps        |  scatter_mapbox, line_mapbox, choropleth_mapbox, density_mapbox |
# | Outline Maps     |  scatter_geo, line_geo, choropleth                              |
# | Polar Charts     |  scatter_polar, line_polar, bar_polar                           |
# | Ternary Charts   |  scatter_ternary, line_ternary                                  |

# %% [markdown]
# # **3 <font color='orange'>|</font> Import und Basisdaten**
# ---

# %%
import plotly.express as px

tips = px.data.tips()
gapminder = px.data.gapminder()
oceania = px.data.gapminder().query("continent=='Oceania'")
iris = px.data.iris()

# %% [markdown]
# # **4 <font color='orange'>|</font> Scatter**
# ---

# %% [markdown]
# [Beispiele](https://plotly.com/python/line-and-scatter/)

# %% [markdown]
# <p><font color='black' size="5">
# Simple Scatter Chart
# </font></p>

# %%
fig = px.scatter(tips,
                 x="total_bill",
                 y="tip",
                 title = "Analyse Trinkgeld",
                 labels={"total_bill": "Rechnung","tip": "Trinkgeld"},
                 width=800, height=400)
fig.show()

# %% [markdown]
# <p><font color='black' size="5">
# Scatter and Trendline
# </font></p>

# %% [markdown]
# [Beispiele](https://plotly.com/python/linear-fits/)

# %%
fig = px.scatter(tips,
                 x="total_bill",
                 y="tip",
                 trendline="ols",
                 trendline_color_override="red",
                 width=800, height=400)
fig.show()

# %% [markdown]
# <p><font color='black' size="5">
# Scatter, Line and Marginals
# </font></p>

# %%
fig = px.scatter(tips,
                 x="total_bill",
                 y="tip",
                 color="time",
                 marginal_y="box",
                 marginal_x="box",
                 trendline="ols",
                 width=1000, height=500)
fig.show()

# %% [markdown]
# <p><font color='black' size="5">
# Scatter Matrix
# </font></p>

# %%
fig = px.scatter_matrix(tips,
                        color="time",
                        width=1000,
                        height=1000)
fig.show()

# %% [markdown]
# <p><font color='black' size="5">
# Scatter Animated
# </font></p>

# %%
px.scatter(gapminder[gapminder['continent'] == 'Europe'],
           x='lifeExp',
           range_x=[40,90],
           y="gdpPercap",
           range_y=[800,42000],
           color='country',
           size ='pop',
           title = "Lebenserwartung im Zeitablauf",
           labels={"year": "Jahr","lifeExp": "Lebenserwartung", "gdpPercap": "Bruttoinlandsprodukt (BIP) pro Kopf "},
           animation_frame="year",
           width=1200,
           height=600)

# %% [markdown]
# # **5 <font color='orange'>|</font> Line**
# ---

# %% [markdown]
# [Beispiele](https://plotly.com/python/line-charts/)

# %%
fig = px.line(oceania,
              x="year",
              y="lifeExp",
              color='country',
              width=1200,
              height=600)
fig.show()

# %%
fig = px.line(oceania,
              x="lifeExp",
              y="gdpPercap",
              color="country",
              text="year",
              width=1200,
              height=600)
fig.update_traces(textposition="bottom right")
fig.show()

# %% [markdown]
# # **6 <font color='orange'>|</font> Box**
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Beispiele](https://plotly.com/python/box-plots/)

# %%
fig = px.box(tips,
             y="total_bill",
             title = "Boxplot Tip-Analyse",
             labels={"total_bill": "Rechnungsbetrag"},
             width=400,
             height=400)

fig.show()

# %%
fig = px.box(tips,
             x="time",
             y="total_bill",
             title = "Boxplot Tip-Analyse",
             labels={"total_bill": "Rechnungsbetrag", "time": "Essenszeit"},
             width=600,
             height=400)
fig.show()

# %%
color_discrete_map={"Dinner": "red", "Lunch": "blue"}

# %%
fig = px.box(tips,
             x="time",
             y="total_bill",
             points="all",
             title = "Boxplot Tip-Analyse",
             labels={"total_bill": "Rechnungsbetrag", "time": "Essenszeit"},
             width=600,
             height=400)
fig.show()

# %%
fig = px.box(tips,
             x="time",
             y="total_bill",
             points="all",
             color="sex",
             width=1000,
             height=400)
fig.show()

# %%
fig = px.box(tips,
             x="day",
             y="total_bill",
             color="smoker")
fig.show()

# %% [markdown]
# # **7 <font color='orange'>|</font> Bar**
# ---

# %% [markdown]
# <p><font color='black' size="5">
# Simple Bar Chart
# </font></p>

# %%
fig = px.bar(gapminder[gapminder['country'] == 'Canada'],
             x='year',
             y='pop',
             text_auto=".2s",
             width=800,
             height=400)
fig.show()

# %%
px.bar(oceania,
       x='year',
       y='pop',
       text_auto=".2s",
       title="Bevölkerungsentwicklung",
       width=1200,
       height=600)

# %%
fig = px.bar(tips,
             x="sex",
             y="total_bill",
             width=1000,
             height=500)
fig.show()

# %%
fig = px.bar(tips,
             x="sex",
             y="total_bill",
             color="smoker",
             width=800,
             height=500)
fig.show()

# %% [markdown]
# <p><font color='black' size="5">
# Bar Chart Grouped
# </font></p>

# %%
fig = px.bar(tips,
             x="sex",
             y="total_bill",
             color="smoker",
             barmode="group",
             width=800,
             height=500)
fig.show()

# %% [markdown]
# <p><font color='black' size="5">
# Bar Chart Matrix
# </font></p>

# %%
fig = px.bar(tips,
             x="sex",
             y="total_bill",
             color="smoker",
             barmode="group",
             facet_row="time",
             facet_col="day",
             category_orders={"day": ["Thur", "Fri", "Sat", "Sun"], "time": ["Lunch", "Dinner"]} ,
             width=1000,
             height=500)
fig.show()

# %% [markdown]
# # **8 <font color='orange'>|</font> Parallels**
# ---

# %% [markdown]
# <p><font color='black' size="5">
# Parallel Coordinates
# </font></p>

# %% [markdown]
# [Beispiele](https://plotly.com/python/parallel-coordinates-plot/)

# %%
fig = px.parallel_coordinates(iris,
                              color="species_id",
                              dimensions=['sepal_width', 'sepal_length', 'petal_width', 'petal_length'],
                              width=1000,
                              height=500)
fig.show()

# %% [markdown]
# <p><font color='black' size="5">
# Parallel Categories
# </font></p>

# %% [markdown]
# [Beispiele](https://plotly.com/python/parallel-categories-diagram/)

# %%
fig = px.parallel_categories(tips,
                             color="size",
                             color_continuous_scale=px.colors.sequential.RdBu,
                             width=1000,
                             height=500)
fig.show()

# %% [markdown]
# # **9 <font color='orange'>|</font> Funnel**
# ---

# %% [markdown]
# [Beispiele](https://plotly.com/python/funnel-charts/)

# %%
funnel = dict(
    Stage=["Visit website", "View Products", "Add to basket", "Checkout"],
    Values=[100, 43, 25, 2])

fig = px.funnel(funnel,
                x='Values',
                y='Stage',
                title='E-Commerce Funnel',
                width=800,
                height=500)
fig.show()

# %% [markdown]
# # **10 <font color='orange'>|</font> Waterfall**
# ---

# %% [markdown]
# [Beispiele](https://plotly.com/python/waterfall-charts/)

# %%
import plotly.graph_objects as go

steps = ["2021", "Sales", "Consulting", "Net revenue", "Purchases", "Other expenses", "2022"]
values = [100, 60, 80, 0, -40, -60, 0]
position = ["absolute", "relative","relative", "total", "relative", "relative", "total"]
text_ = ["Total", "+60", "+80", "", "-40", "-60", "Total"]

fig = go.Figure(go.Waterfall(
    name = "Company A",
    orientation = "v",
    measure = position,
    x = steps,
    y = values,
    base = 0,
    textposition = "outside",
    text = text_,
    connector = {"line":{"color":"black"}},
))

fig.update_layout(
        title = "P&L Reconciliation",
        width=1000,
        height=500,
        showlegend = True)

fig.show()
